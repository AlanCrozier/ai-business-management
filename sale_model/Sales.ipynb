# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
data=pd.read_csv("C:\\Users\\alanc\\AI_Business_management\\Data\\sales_dataset.csv")

# %%
data.head()
# Out:
#    order_id        date  customer_id product_id  employee_id region  \
# 0     90000  2023-06-20         6396       P102         2375   East
# 1     90001  2023-06-01         5173       P105         2067  North
# 2     90002  2023-06-14         8394       P101         2963  South
# 3     90003  2023-10-24         7623       P104         1773  South
# 4     90004  2023-04-14         7888       P105         1911  South
#
#    units_sold  revenue
# 0           2      190
# 1           3      180
# 2           1      150
# 3           1       25
# 4           1       60

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     20000 non-null  int64
#  1   date         20000 non-null  str
#  2   customer_id  20000 non-null  int64
#  3   product_id   20000 non-null  str
#  4   employee_id  20000 non-null  int64
#  5   region       20000 non-null  str
#  6   units_sold   20000 non-null  int64
#  7   revenue      20000 non-null  int64
# dtypes: int64(5), str(3)
# memory usage: 1.2 MB

# %%
data.isnull().sum()
# Out:
# order_id       0
# date           0
# customer_id    0
# product_id     0
# employee_id    0
# region         0
# units_sold     0
# revenue        0
# dtype: int64
